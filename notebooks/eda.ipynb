# %% [markdown]
# ## Importando bibliotecas

# %%
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')
import sys
from util import *
import gc
import pickle

import warnings

# Ignorar todos os warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Lendo os dados

# %%
df = pd.read_parquet("../data/df.parquet")
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#    Churn
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %% [markdown]
# ## Entendimento dos dados e do target

# %%
df.shape
# Out:
# (7043, 20)

# %%
metadados = generate_metadata(df=df, targets=['Churn'], orderby='CARDINALIDADE')
metadados
# Out:
#              FEATURE  USO_FEATURE  QT_NULOS  PC_NULOS  CARDINALIDADE  \
# 0       TotalCharges  Explicativa        11      0.16           6530
# 1     MonthlyCharges  Explicativa         0      0.00           1585
# 2             tenure  Explicativa         0      0.00             73
# 3      PaymentMethod  Explicativa         0      0.00              4
# 4    StreamingMovies  Explicativa         0      0.00              3
# 5        TechSupport  Explicativa         0      0.00              3
# 6       OnlineBackup  Explicativa         0      0.00              3
# 7        StreamingTV  Explicativa         0      0.00              3
# 8   DeviceProtection  Explicativa         0      0.00              3
# 9      MultipleLines  Explicativa         0      0.00              3
# 10   InternetService  Explicativa         0      0.00              3
# 11    OnlineSecurity  Explicativa         0      0.00              3
# 12          Contract  Explicativa         0      0.00              3
# 13           Partner  Explicativa         0      0.00              2
# 14     SeniorCitizen  Explicativa         0      0.00              2
# 15            gender  Explicativa         0      0.00              2
# 16        Dependents  Explicativa         0      0.00              2
# 17      PhoneService  Explicativa         0      0.00              2
# 18  PaperlessBilling  Explicativa         0      0.00              2
# 19             Churn       Target         0      0.00              2
#
#    TIPO_FEATURE
# 0       float64
# 1       float64
# 2         int64
# 3        object
# 4        object
# 5        object
# 6        object
# 7        object
# 8        object
# 9        object
# 10       object
# 11       object
# 12       object
# 13       object
# 14        int64
# 15       object
# 16       object
# 17       object
# 18       object
# 19        int64

# %%
### Entendimento da variável resposta
target_counts = df['Churn'].value_counts()

# Calculando percentuais de churn
percent_n = (target_counts[0] / len(df)) * 100
percent_s = (target_counts[1] / len(df)) * 100

# Criando dataframe
total_por_target = pd.DataFrame({'target': ['Nao', 'Sim'], 'Percentual': [percent_n, percent_s]})

#Definição de cores
cores = {'Nao': 'lightgrey', 'Sim': 'royalblue'}

# Plot do gráfico
ax = sns.barplot(x='target', y='Percentual', hue='target', data=total_por_target, palette=cores, dodge=False)

# Adicionando valores de cada barra
for p in ax.patches:
    ax.annotate("{:.2f}%".format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.xlabel('target')
plt.ylabel('Percentual')
plt.title('Percentual de target')
plt.show()

# %% [markdown]
# ## Análises univariadas e bivariadas

# %%
import math
# Variáveis de interesse
target = 'Churn'

categorical_vars = df.select_dtypes(include=['object', 'category']).columns.tolist()
numerical_vars = df.select_dtypes(exclude=['object', 'category']).columns.tolist()

# Remove o target da lista de variáveis categóricas
if target in numerical_vars:
    numerical_vars.remove(target)

# --------------------
# Execução das análises
# --------------------

print("🔹 Análise Univariada - Variáveis Categóricas")
univariate_categorical(df, categorical_vars)

print("🔹 Análise Univariada - Variáveis Numéricas")
univariate_numerical(df, numerical_vars)

print("🔹 Análise Bivariada - Variáveis Categóricas vs Alvo")
bivariate_categorical_target(df, categorical_vars, target)

print("🔹 Análise Bivariada - Variáveis Numéricas vs Alvo")
bivariate_numerical_target(df, numerical_vars, target)
# Out:
# 🔹 Análise Univariada - Variáveis Categóricas
# 🔹 Análise Univariada - Variáveis Numéricas
# 🔹 Análise Bivariada - Variáveis Categóricas vs Alvo
# 🔹 Análise Bivariada - Variáveis Numéricas vs Alvo

# %%
df_iv = analise_iv(df, 'Churn')
df_iv.get_lista_iv()
# Out:
# Churn               IV
# Variavel
# Contract          1.24
# tenure            0.81
# OnlineSecurity    0.72
# TechSupport       0.70
# InternetService   0.62
# OnlineBackup      0.52
# DeviceProtection  0.50
# PaymentMethod     0.46
# StreamingMovies   0.38
# StreamingTV       0.38
# MonthlyCharges    0.36
# TotalCharges      0.34
# PaperlessBilling  0.20
# Dependents        0.15
# Partner           0.12
# MultipleLines     0.00
# SeniorCitizen     0.00
# PhoneService      0.00
# gender            0.00

# %%
df_iv.get_bivariada(var_escolhida='Contract')
# Out:
# ==> "Contract" tem IV de 1.24
# Churn  Variavel       Var_Range  #Target_1  #Target_0  Total  %Freq  \
# 0      Contract  Month-to-month       1655       2220   3875  55.02
# 1      Contract        One year        166       1307   1473  20.91
# 2      Contract        Two year         48       1647   1695  24.07
#
# Churn  %Target_1  %Target_0  %Taxa_de_Target_1  Odds  LN(Odds)    IV
# 0          88.55      42.91              42.71  2.06      0.72  0.33
# 1           8.88      25.26              11.27  0.35     -1.05  0.17
# 2           2.57      31.83               2.83  0.08     -2.53  0.74

# %%
df_iv.get_bivariada(var_escolhida='tenure')
# Out:
# ==> "tenure" tem IV de 0.81
# Churn Variavel     Var_Range  #Target_1  #Target_0  Total  %Freq  %Target_1  \
# 0       tenure  (-0.01, 2.0]        503        359    862  12.24      26.91
# 1       tenure    (2.0, 6.0]        281        338    619   8.79      15.03
# 2       tenure   (6.0, 12.0]        253        452    705  10.01      13.54
# 3       tenure  (12.0, 20.0]        214        478    692   9.83      11.45
# 4       tenure  (20.0, 29.0]        158        533    691   9.81       8.45
# 5       tenure  (29.0, 40.0]        157        560    717  10.18       8.40
# 6       tenure  (40.0, 50.0]        115        537    652   9.26       6.15
# 7       tenure  (50.0, 60.0]         95        603    698   9.91       5.08
# 8       tenure  (60.0, 69.0]         70        686    756  10.73       3.75
# 9       tenure  (69.0, 72.0]         23        628    651   9.24       1.23
#
# Churn  %Target_0  %Taxa_de_Target_1  Odds  LN(Odds)    IV
# 0           6.94              58.35  3.88      1.36  0.27
# 1           6.53              45.40  2.30      0.83  0.07
# 2           8.74              35.89  1.55      0.44  0.02
# 3           9.24              30.92  1.24      0.22  0.00
# 4          10.30              22.87  0.82     -0.20  0.00
# 5          10.82              21.90  0.78     -0.25  0.01
# 6          10.38              17.64  0.59     -0.53  0.02
# 7          11.65              13.61  0.44     -0.82  0.05
# 8          13.26               9.26  0.28     -1.27  0.12
# 9          12.14               3.53  0.10     -2.30  0.25

# %%
df_iv.get_bivariada(var_escolhida='OnlineSecurity')
# Out:
# ==> "OnlineSecurity" tem IV de 0.72
# Churn        Variavel            Var_Range  #Target_1  #Target_0  Total  \
# 0      OnlineSecurity                   No       1461       2037   3498
# 1      OnlineSecurity  No internet service        113       1413   1526
# 2      OnlineSecurity                  Yes        295       1724   2019
#
# Churn  %Freq  %Target_1  %Target_0  %Taxa_de_Target_1  Odds  LN(Odds)    IV
# 0      49.67      78.17      39.37              41.77  1.99      0.69  0.27
# 1      21.67       6.05      27.31               7.40  0.22     -1.51  0.32
# 2      28.67      15.78      33.32              14.61  0.47     -0.76  0.13

# %%
df_iv.get_bivariada(var_escolhida='TechSupport')
# Out:
# ==> "TechSupport" tem IV de 0.7
# Churn     Variavel            Var_Range  #Target_1  #Target_0  Total  %Freq  \
# 0      TechSupport                   No       1446       2027   3473  49.31
# 1      TechSupport  No internet service        113       1413   1526  21.67
# 2      TechSupport                  Yes        310       1734   2044  29.02
#
# Churn  %Target_1  %Target_0  %Taxa_de_Target_1  Odds  LN(Odds)    IV
# 0          77.37      39.18              41.64  1.97      0.68  0.26
# 1           6.05      27.31               7.40  0.22     -1.51  0.32
# 2          16.59      33.51              15.17  0.50     -0.69  0.12

# %%
df_iv.get_bivariada(var_escolhida='PaymentMethod')
# Out:
# ==> "PaymentMethod" tem IV de 0.46
# Churn       Variavel                  Var_Range  #Target_1  #Target_0  Total  \
# 0      PaymentMethod  Bank transfer (automatic)        258       1286   1544
# 1      PaymentMethod    Credit card (automatic)        232       1290   1522
# 2      PaymentMethod           Electronic check       1071       1294   2365
# 3      PaymentMethod               Mailed check        308       1304   1612
#
# Churn  %Freq  %Target_1  %Target_0  %Taxa_de_Target_1  Odds  LN(Odds)    IV
# 0      21.92      13.80      24.86              16.71  0.56     -0.58  0.06
# 1      21.61      12.41      24.93              15.24  0.50     -0.69  0.09
# 2      33.58      57.30      25.01              45.29  2.29      0.83  0.27
# 3      22.89      16.48      25.20              19.11  0.65     -0.43  0.04

# %%
df_iv.get_bivariada(var_escolhida='InternetService')
# Out:
# ==> "InternetService" tem IV de 0.62
# Churn         Variavel    Var_Range  #Target_1  #Target_0  Total  %Freq  \
# 0      InternetService          DSL        459       1962   2421  34.37
# 1      InternetService  Fiber optic       1297       1799   3096  43.96
# 2      InternetService           No        113       1413   1526  21.67
#
# Churn  %Target_1  %Target_0  %Taxa_de_Target_1  Odds  LN(Odds)    IV
# 0          24.56      37.92              18.96  0.65     -0.43  0.06
# 1          69.40      34.77              41.89  2.00      0.69  0.24
# 2           6.05      27.31               7.40  0.22     -1.51  0.32

# %%
df_iv.get_bivariada(var_escolhida='TotalCharges')
# Out:
# ==> "TotalCharges" tem IV de 0.34
# Churn      Variavel           Var_Range  #Target_1  #Target_0  Total  %Freq  \
# 0      TotalCharges       (18.79, 84.6]        369        336    705  10.03
# 1      TotalCharges      (84.6, 267.07]        278        424    702   9.98
# 2      TotalCharges     (267.07, 552.0]        215        488    703  10.00
# 3      TotalCharges     (552.0, 944.17]        192        511    703  10.00
# 4      TotalCharges   (944.17, 1397.48]        155        548    703  10.00
# 5      TotalCharges  (1397.48, 2048.95]        137        566    703  10.00
# 6      TotalCharges  (2048.95, 3141.13]        198        505    703  10.00
# 7      TotalCharges  (3141.13, 4475.41]        126        577    703  10.00
# 8      TotalCharges  (4475.41, 5976.64]        111        592    703  10.00
# 9      TotalCharges   (5976.64, 8684.8]         88        616    704  10.01
#
# Churn  %Target_1  %Target_0  %Taxa_de_Target_1  Odds  LN(Odds)    IV
# 0          19.74       6.51              52.34  3.03      1.11  0.15
# 1          14.87       8.21              39.60  1.81      0.59  0.04
# 2          11.50       9.45              30.58  1.22      0.20  0.00
# 3          10.27       9.90              27.31  1.04      0.04  0.00
# 4           8.29      10.61              22.05  0.78     -0.25  0.01
# 5           7.33      10.96              19.49  0.67     -0.40  0.01
# 6          10.59       9.78              28.17  1.08      0.08  0.00
# 7           6.74      11.18              17.92  0.60     -0.51  0.02
# 8           5.94      11.47              15.79  0.52     -0.65  0.04
# 9           4.71      11.93              12.50  0.39     -0.94  0.07
